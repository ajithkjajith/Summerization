# %%
import urllib2
urllib2.download()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-2e8a2f0b58d0> in <module>()
# ----> 1 import urllib2
#       2 urllib2.download()
#
# ModuleNotFoundError: No module named 'urllib2'

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("http://anengineersblog.com/").read().decode('utf8','ignore')
soap = BeautifulSoup(html,'lxml')
text = ' '.join(map(lambda p:p.text,soap.find_all('article')))
#print(text.encode('utf8').rstrip("\n"))
ajith = text.encode('ascii',errors='replace').decode().replace("\n",".")

from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.corpus import stopwords
from string import punctuation

from collections import defaultdict

def sum(ajith,n):
    sents = sent_tokenize(ajith)
    assert n<=len(sents)
    word_sent = word_tokenize(ajith.lower())
    stopw = set(stopwords.words('english')+list(punctuation))
    
    word_sent = [word for word in word_sent if word not in stopw]
    from nltk.probability import freqDist
    freq = FreqDist(word_sent)
    
    ranking = defaultdict(int)
    for i,sent in enumerate(sents):
        for w in word_tokenize(sent.lower()):
            if w in freq:
                ranking[i] += freq[w]
    
    sents_idx = nlargest(n,ranking,key=ranking.get)
    return (sents[j] for j in sorted(sents_idx))


sum(ajith,3)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      79             except LookupError as e:
# ---> 80                 try: root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      81                 except LookupError: raise e
#
# ~\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     674     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 675     raise LookupError(resource_not_found)
#     676
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   Searched in:
#     - 'C:\\Users\\User/nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# ...

# %%
import nltk

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("http://anengineersblog.com/").read().decode('utf8','ignore')
soap = BeautifulSoup(html,'lxml')
text = ' '.join(map(lambda p:p.text,soap.find_all('article')))
#print(text.encode('utf8').rstrip("\n"))
ajith = text.encode('ascii',errors='replace').decode().replace("\n",".")

from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.corpus import stopwords
from string import punctuation
from nltk.probability import FreqDist
from collections import defaultdict
from heapq import nlargest

def sum(ajith,n):
    sents = sent_tokenize(ajith)
    assert n<=len(sents)
    word_sent = word_tokenize(ajith.lower())
    stopw = set(stopwords.words('english')+list(punctuation))
    
    word_sent = [word for word in word_sent if word not in stopw]
   
    freq = FreqDist(word_sent)
    
    ranking = defaultdict(int)
    for i,sent in enumerate(sents):
        for w in word_tokenize(sent.lower()):
            if w in freq:
                ranking[i] += freq[w]
    
    sents_idx = nlargest(n,ranking,key=ranking.get)
    return (sents[j] for j in sorted(sents_idx))


sum(ajith,3)
# Out:
# <generator object sum.<locals>.<genexpr> at 0x000000236B498048>

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("http://anengineersblog.com/").read().decode('utf8','ignore')
soap = BeautifulSoup(html,'lxml')
text = ' '.join(map(lambda p:p.text,soap.find_all('article')))
#print(text.encode('utf8').rstrip("\n"))
ajith = text.encode('ascii',errors='replace').decode().replace("\n"," ")
ajith
# Out:
# ''

# %%
ajith
# Out:
# '..Are shopping site reviews fake?.Standard...I am a regular online shopper and buys lot of stuff online. I always prefer to buy from shopping website?s retail/official warehouse just to ensure that I am receiving original products..Recently, I thought of upgrading my old desktop PC (Mobo Intel DP45SG) by adding up two 2GB DDR3 1333MHZ 2RX8 Dual channel RAM sticks. I started searching online for similar listings and found Kingston KVR1333D3N9/2G in two famous Indian shopping websites. Though the sellers were not official warehouse of the website, I even ordered one RAM stick on last Saturday from one of the website which at the time of writing is still awaiting dispatch. As I was checking the website today to know the status, I noticed lot of 4 star and 5 star reviews for the item/seller. Out of curiosity, I just checked the other shopping website and found these similarities for the same product..Website 1..Website 2..In the above two images, except the number of months, everything 
# ...

# %%
from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.corpus import stopwords
from string import punctuation
sents=sent_tokenize(ajith)
print(sents)
# Out:
# ['..Are shopping site reviews fake?.Standard...I am a regular online shopper and buys lot of stuff online.', 'I always prefer to buy from shopping website?s retail/official warehouse just to ensure that I am receiving original products..Recently, I thought of upgrading my old desktop PC (Mobo Intel DP45SG) by adding up two 2GB DDR3 1333MHZ 2RX8 Dual channel RAM sticks.', 'I started searching online for similar listings and found Kingston KVR1333D3N9/2G in two famous Indian shopping websites.', 'Though the sellers were not official warehouse of the website, I even ordered one RAM stick on last Saturday from one of the website which at the time of writing is still awaiting dispatch.', 'As I was checking the website today to know the status, I noticed lot of 4 star and 5 star reviews for the item/seller.', 'Out of curiosity, I just checked the other shopping website and found these similarities for the same product..Website 1..Website 2..In the above two images, except the number of mon
# ...

# %%
words = word_tokenize(ajith.lower())
print(words)
# Out:
# ['..are', 'shopping', 'site', 'reviews', 'fake', '?', '.standard', '...', 'i', 'am', 'a', 'regular', 'online', 'shopper', 'and', 'buys', 'lot', 'of', 'stuff', 'online', '.', 'i', 'always', 'prefer', 'to', 'buy', 'from', 'shopping', 'website', '?', 's', 'retail/official', 'warehouse', 'just', 'to', 'ensure', 'that', 'i', 'am', 'receiving', 'original', 'products..recently', ',', 'i', 'thought', 'of', 'upgrading', 'my', 'old', 'desktop', 'pc', '(', 'mobo', 'intel', 'dp45sg', ')', 'by', 'adding', 'up', 'two', '2gb', 'ddr3', '1333mhz', '2rx8', 'dual', 'channel', 'ram', 'sticks', '.', 'i', 'started', 'searching', 'online', 'for', 'similar', 'listings', 'and', 'found', 'kingston', 'kvr1333d3n9/2g', 'in', 'two', 'famous', 'indian', 'shopping', 'websites', '.', 'though', 'the', 'sellers', 'were', 'not', 'official', 'warehouse', 'of', 'the', 'website', ',', 'i', 'even', 'ordered', 'one', 'ram', 'stick', 'on', 'last', 'saturday', 'from', 'one', 'of', 'the', 'website', 'which', 'at', 'the', 'tim
# ...

# %%
stops= set(stopwords.words('english')+list(punctuation))
print(stops)
# Out:
# {"shan't", 'is', 'such', 'have', 'having', 'll', 'been', "mightn't", 'the', 'as', "hasn't", "she's", 'too', "won't", 'nor', 'y', 'not', 'should', "wasn't", '~', 'where', '^', 'won', 'while', 'aren', 'further', 'our', 'above', "didn't", 'on', 'didn', "shouldn't", 'him', '!', 'both', 'yours', 'his', 'than', 'ours', "needn't", 'about', 'in', "should've", 'same', 'theirs', 'only', 'do', '*', 'until', 'yourself', 'herself', 'it', 'don', '$', "'", "you'll", 'who', 'again', 'during', 'very', '+', ':', '>', '\\', 'some', 'we', 'mightn', "doesn't", 'hers', '-', "don't", 'now', 'that', 'down', 'was', 'ma', 'itself', 'to', 'whom', 'for', 'yourselves', 'after', 'being', '=', 'most', 'this', 'against', 'be', 'they', 'over', 'more', 'below', 'he', 'himself', 'why', '@', 'then', 'ourselves', 'and', 'all', 'an', 'she', 'mustn', ']', 'few', 'between', 'out', 'once', 'had', '`', 're', 'each', "aren't", 'by', 'these', '#', 'off', 'can', 'but', '.', 'here', 'd', "hadn't", '?', "mustn't", 'doesn', 'or', 
# ...

# %%
word_sent = [word for word in word_sent if word not in stopw]
print(word_sent)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-27d6ba9e83bd> in <module>()
# ----> 1 word_sent = [word for word in word_sent if word not in stopw]
#       2 print(word_sent)
#
# NameError: name 'word_sent' is not defined

# %%
word_sent = word_tokenize(ajith.lower())
stopw = set(stopwords.words('english')+list(punctuation))
    
word_sent = [word for word in word_sent if word not in stopw]
print(word_sent)
# Out:
# ['..are', 'shopping', 'site', 'reviews', 'fake', '.standard', '...', 'regular', 'online', 'shopper', 'buys', 'lot', 'stuff', 'online', 'always', 'prefer', 'buy', 'shopping', 'website', 'retail/official', 'warehouse', 'ensure', 'receiving', 'original', 'products..recently', 'thought', 'upgrading', 'old', 'desktop', 'pc', 'mobo', 'intel', 'dp45sg', 'adding', 'two', '2gb', 'ddr3', '1333mhz', '2rx8', 'dual', 'channel', 'ram', 'sticks', 'started', 'searching', 'online', 'similar', 'listings', 'found', 'kingston', 'kvr1333d3n9/2g', 'two', 'famous', 'indian', 'shopping', 'websites', 'though', 'sellers', 'official', 'warehouse', 'website', 'even', 'ordered', 'one', 'ram', 'stick', 'last', 'saturday', 'one', 'website', 'time', 'writing', 'still', 'awaiting', 'dispatch', 'checking', 'website', 'today', 'know', 'status', 'noticed', 'lot', '4', 'star', '5', 'star', 'reviews', 'item/seller', 'curiosity', 'checked', 'shopping', 'website', 'found', 'similarities', 'product..website', '1..website', 
# ...

# %%
from nltk.probability import FreqDist
freq = FreqDist(word_sent)
freq
# Out:
# FreqDist({'...': 17, 'ghost': 8, 'wordpress': 7, 'website': 5, 'blog': 5, 'shopping': 4, 'content': 4, 'editor': 4, 'summernote': 4, 'reviews': 3, ...})

# %%
from collections import defaultdict
ranking = defaultdict(int)
for i,sent in enumerate(sents):
    for w in word_tokenize(sent.lower()):
        if w in freq:
            ranking[i] += freq[w]
    
ranking
# Out:
# defaultdict(int,
#             {0: 42,
#              1: 41,
#              2: 23,
#              3: 37,
#              4: 25,
#              5: 33,
#              6: 11,
#              7: 3,
#              8: 144,
#              9: 55,
#              10: 33,
#              11: 58,
#              12: 9,
#              13: 15,
#              14: 27,
#              15: 30,
#              16: 94,
#              17: 97,
#              18: 26,
#              19: 11,
#              20: 10,
#              21: 6,
#              22: 14,
#              23: 18,
#              24: 74,
#              25: 5,
#              26: 116})

# %%
from heapq import nlargest
sents_idx = nlargest(4,ranking,key=ranking.get)
sents_idx
# Out:
# [8, 26, 17, 16]

# %%
[sents[j] for j in sorted(sents_idx)]
# Out:
# ['or Is this a mere coincidence?......Date.September 4, 2017....Comments.Leave a comment ... ..Why I migrated my blog back to WordPress from Ghost.Standard...I started this blog almost 4 years back (as of 29 june 2017) and still keep it running.',
#  'Not everyone is having free time to login the server and update the scripts, whenever a new version is out..When thinking of HTML, custom CSS along with the Ghost Markdown Scripting, what a pain..When I started using, there wasn?t any plugins for Ghost...In the End, I would like to say that Ghost is good when more emphasis is given for security, performance, simplicity and content.',
#  'And WordPress is suitable if you really want to deliver an out of the box, interactive Blog.......Date.June 29, 2017....Comments.Leave a comment ...',
#  '});..For more information, check out summer note at http://summernote.org......Date.September 6, 2016....Tags.CONTENT, CSS, EDITOR, HTML, JAVASCRIPT ...Comments.Leave a comment ...']

# %%
from heapq import nlargest
sents_idx = nlargest(2,ranking,key=ranking.get)
[sents[j] for j in sorted(sents_idx)]
# Out:
# ['or Is this a mere coincidence?......Date.September 4, 2017....Comments.Leave a comment ... ..Why I migrated my blog back to WordPress from Ghost.Standard...I started this blog almost 4 years back (as of 29 june 2017) and still keep it running.',
#  '});..For more information, check out summer note at http://summernote.org......Date.September 6, 2016....Tags.CONTENT, CSS, EDITOR, HTML, JAVASCRIPT ...Comments.Leave a comment ...']

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("http://anengineersblog.com/").read().decode('utf8','ignore')
soap = BeautifulSoup(html,'lxml')
text = ' '.join(map(lambda p:p.text,soap.find_all('article')))
#print(text.encode('utf8').rstrip("\n"))
ajith = text.encode('ascii',errors='replace').decode().replace("\n"," ")

from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.corpus import stopwords
from string import punctuation
sents=sent_tokenize(ajith)

words = word_tokenize(ajith.lower())

stops= set(stopwords.words('english')+list(punctuation))


word_sent = [word for word in word_sent if word not in stopw]

word_sent = word_tokenize(ajith.lower())
stopw = set(stopwords.words('english')+list(punctuation))
    
word_sent = [word for word in word_sent if word not in stopw]


from nltk.probability import FreqDist
freq = FreqDist(word_sent)



from collections import defaultdict
ranking = defaultdict(int)
for i,sent in enumerate(sents):
    for w in word_tokenize(sent.lower()):
        if w in freq:
            ranking[i] += freq[w]
    



from heapq import nlargest
sents_idx = nlargest(2,ranking,key=ranking.get)
[sents[j] for j in sorted(sents_idx)]
# Out:
# ['Date September 4, 2017    Comments Leave a comment       Why I migrated my blog back to WordPress from Ghost Standard   I started this blog almost 4 years back (as of 29 june 2017) and still keep it running.',
#  '<div id="summernote">Hello Summer</div>  and finally, add a function to capture document ready event in your page as follows :  $(document).ready(function() {   $(\'#summernote\').summernote(); });  For more information, check out summer note at http://summernote.org      Date September 6, 2016    Tags CONTENT, CSS, EDITOR, HTML, JAVASCRIPT    Comments Leave a comment']

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("http://anengineersblog.com/").read().decode('utf8','ignore')
soap = BeautifulSoup(html,'lxml')
text = ' '.join(map(lambda p:p.text,soap.find_all('article')))
#print(text.encode('utf8').rstrip("\n"))
ajith = text.encode('ascii',errors='replace').decode().replace("\n","")

from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.corpus import stopwords
from string import punctuation
sents=sent_tokenize(ajith)

words = word_tokenize(ajith.lower())

stops= set(stopwords.words('english')+list(punctuation))


word_sent = [word for word in word_sent if word not in stopw]

word_sent = word_tokenize(ajith.lower())
stopw = set(stopwords.words('english')+list(punctuation))
    
word_sent = [word for word in word_sent if word not in stopw]


from nltk.probability import FreqDist
freq = FreqDist(word_sent)



from collections import defaultdict
ranking = defaultdict(int)
for i,sent in enumerate(sents):
    for w in word_tokenize(sent.lower()):
        if w in freq:
            ranking[i] += freq[w]
    
ranking


from heapq import nlargest
sents_idx = nlargest(2,ranking,key=ranking.get)
[sents[j] for j in sorted(sents_idx)]

print("the article is talking about")
print(nlargest(4,freq,key=freq.get))
[sents[j] for j in sorted(sents_idx)]
# Out:
# the article is talking about
# ['wordpress', 'ghost', 'website', 'shopping']
# ['Not everyone is having free time to login the server and update the scripts, whenever a new version is out.When thinking of HTML, custom CSS along with the Ghost Markdown Scripting, what a pain.When I started using, there wasn?t any plugins for Ghost.In the End, I would like to say that Ghost is good when more emphasis is given for security, performance, simplicity and content.',
# ...

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("http://anengineersblog.com/").read().decode('utf8','ignore')
soap = BeautifulSoup(html,'lxml')
text = ' '.join(map(lambda p:p.text,soap.find_all('article')))
#print(text.encode('utf8').rstrip("\n"))
ajith = text.encode('ascii',errors='replace').decode().replace("\n",".")

from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.corpus import stopwords
from string import punctuation
sents=sent_tokenize(ajith)

words = word_tokenize(ajith.lower())

stops= set(stopwords.words('english')+list(punctuation))


word_sent = [word for word in word_sent if word not in stopw]

word_sent = word_tokenize(ajith.lower())
stopw = set(stopwords.words('english')+list(punctuation))
    
word_sent = [word for word in word_sent if word not in stopw]


from nltk.probability import FreqDist
freq = FreqDist(word_sent)



from collections import defaultdict
ranking = defaultdict(int)
for i,sent in enumerate(sents):
    for w in word_tokenize(sent.lower()):
        if w in freq:
            ranking[i] += freq[w]
    



from heapq import nlargest
sents_idx = nlargest(2,ranking,key=ranking.get)


print('\033[1m'+'The ARTICLE is talking about')
print(nlargest(4,freq,key=freq.get))
print('\033[1m' + 'SUMMARISED')
[sents[j] for j in sorted(sents_idx)]
# Out:
# The ARTICLE is talking about
# ['...', 'ghost', 'wordpress', 'website']
# SUMMARISED
# ['or Is this a mere coincidence?......Date.September 4, 2017....Comments.Leave a comment ... ..Why I migrated my blog back to WordPress from Ghost.Standard...I started this blog almost 4 years back (as of 29 june 2017) and still keep it running.',
#  '});..For more information, check out summer note at http://summernote.org......Date.September 6, 2016....Tags.CONTENT, CSS, EDITOR, HTML, JAVASCRIPT ...Comments.Leave a comment ...']

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("http://anengineersblog.com/").read().decode('utf8','ignore')
soap = BeautifulSoup(html,'lxml')
text = ' '.join(map(lambda p:p.text,soap.find_all('article')))
#print(text.encode('utf8').rstrip("\n"))
ajith = text.encode('ascii',errors='replace').decode().replace("\n",".")

from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.corpus import stopwords
from string import punctuation
sents=sent_tokenize(ajith)

words = word_tokenize(ajith.lower())

stops= set(stopwords.words('english')+list(punctuation))


word_sent = [word for word in word_sent if word not in stopw]

word_sent = word_tokenize(ajith.lower())
stopw = set(stopwords.words('english')+list(punctuation))
    
word_sent = [word for word in word_sent if word not in stopw]


from nltk.probability import FreqDist
freq = FreqDist(word_sent)



from collections import defaultdict
ranking = defaultdict(int)
for i,sent in enumerate(sents):
    for w in word_tokenize(sent.lower()):
        if w in freq:
            ranking[i] += freq[w]
    



from heapq import nlargest
sents_idx = nlargest(2,ranking,key=ranking.get)


print('\033[1m'+'The ARTICLE is talking about')
print(nlargest(4,freq,key=freq.get))

print('\033[1m' + 'SUMMARISED')
[sents[j] for j in sorted(sents_idx)]
# Out:
# The ARTICLE is talking about
# ['...', 'ghost', 'wordpress', 'website']
# SUMMARISED
# ['or Is this a mere coincidence?......Date.September 4, 2017....Comments.Leave a comment ... ..Why I migrated my blog back to WordPress from Ghost.Standard...I started this blog almost 4 years back (as of 29 june 2017) and still keep it running.',
#  '});..For more information, check out summer note at http://summernote.org......Date.September 6, 2016....Tags.CONTENT, CSS, EDITOR, HTML, JAVASCRIPT ...Comments.Leave a comment ...']

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("http://anengineersblog.com/").read().decode('utf8','ignore')
soap = BeautifulSoup(html,'lxml')
text = ' '.join(map(lambda p:p.text,soap.find_all('article')))
#print(text.encode('utf8').rstrip("\n"))
ajith = text.encode('ascii',errors='replace').decode().replace("\n",".")

from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.corpus import stopwords
from string import punctuation
sents=sent_tokenize(ajith)

words = word_tokenize(ajith.lower())

stops= set(stopwords.words('english')+list(punctuation))


word_sent = [word for word in word_sent if word not in stopw]

word_sent = word_tokenize(ajith.lower())
stopw = set(stopwords.words('english')+list(punctuation))
    
word_sent = [word for word in word_sent if word not in stopw]


from nltk.probability import FreqDist
freq = FreqDist(word_sent)



from collections import defaultdict
ranking = defaultdict(int)
for i,sent in enumerate(sents):
    for w in word_tokenize(sent.lower()):
        if w in freq:
            ranking[i] += freq[w]
    



from heapq import nlargest
sents_idx = nlargest(2,ranking,key=ranking.get)
[sents[j] for j in sorted(sents_idx)]

print('\033[1m'+'The ARTICLE is talking about')
print(nlargest(4,freq,key=freq.get))

print('\033[1m' + 'SUMMARISED')
[sents[j] for j in sorted(sents_idx)]
# Out:
# The ARTICLE is talking about
# ['...', 'ghost', 'wordpress', 'website']
# SUMMARISED
# ['or Is this a mere coincidence?......Date.September 4, 2017....Comments.Leave a comment ... ..Why I migrated my blog back to WordPress from Ghost.Standard...I started this blog almost 4 years back (as of 29 june 2017) and still keep it running.',
#  '});..For more information, check out summer note at http://summernote.org......Date.September 6, 2016....Tags.CONTENT, CSS, EDITOR, HTML, JAVASCRIPT ...Comments.Leave a comment ...']

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("https://timesofindia.indiatimes.com/city/kolkata/engineering-student-brother-beat-up-dum-dum-sub-inspector/articleshow/65049669.cms").read().decode('utf8','ignore')
soap = BeautifulSoup(html,'lxml')
text = ' '.join(map(lambda p:p.text,soap.find_all('article')))
#print(text.encode('utf8').rstrip("\n"))
ajith = text.encode('ascii',errors='replace').decode().replace("\n","")

from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.corpus import stopwords
from string import punctuation
sents=sent_tokenize(ajith)

words = word_tokenize(ajith.lower())

stops= set(stopwords.words('english')+list(punctuation))


word_sent = [word for word in word_sent if word not in stopw]

word_sent = word_tokenize(ajith.lower())
stopw = set(stopwords.words('english')+list(punctuation))
    
word_sent = [word for word in word_sent if word not in stopw]


from nltk.probability import FreqDist
freq = FreqDist(word_sent)



from collections import defaultdict
ranking = defaultdict(int)
for i,sent in enumerate(sents):
    for w in word_tokenize(sent.lower()):
        if w in freq:
            ranking[i] += freq[w]
    



from heapq import nlargest
sents_idx = nlargest(2,ranking,key=ranking.get)


print('\033[1m'+'The ARTICLE is talking about')
print(nlargest(4,freq,key=freq.get))

print('\033[94m' + 'SUMMARISED ->')
[sents[j] for j in sorted(sents_idx)]
# Out:
# The ARTICLE is talking about
# []
# SUMMARISED ->
# []

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("https://timesofindia.indiatimes.com/city/kolkata/engineering-student-brother-beat-up-dum-dum-sub-inspector/articleshow/65049669.cms").read().decode('utf8','ignore')
soap = BeautifulSoup(html,'lxml')
text = ' '.join(map(lambda p:p.text,soap.find_all('article')))
#print(text.encode('utf8').rstrip("\n"))
ajith = text.encode('ascii',errors='replace').decode().replace("\n",".")
ajith
# Out:
# ''

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("https://timesofindia.indiatimes.com/city/kolkata/engineering-student-brother-beat-up-dum-dum-sub-inspector/articleshow/65049669.cms").read().decode('utf8','ignore')
soap = BeautifulSoup(html,'lxml')
text = ' '.join(map(lambda p:p.text,soap.find_all('article')))
#print(text.encode('utf8').rstrip("\n"))
ajith = text.encode('ascii',errors='replace').decode().replace("\n",".")
html
# Out:
# '<!DOCTYPE HTML><html xmlns:xslthelper="com.times.utils.xslthelper.XMLHelper" xmlns:dateUtil="com.indiatimes.cms.utilities.CMSDateUtility" xmlns:og="http://ogp.me/ns#" xmlns:fb="http://www.facebook.com/2008/fbml" itemscope="itemscope" itemtype="https://schema.org/NewsArticle"><head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# article: http://ogp.me/ns/article#"><script>\n            function isMobile(){\n                return( function ( a ) {\n\t\t\treturn /(android|bb\\d+|meego).+mobile|avantgo|bada\\/|blackberry|blazer|compal|elaine|fennec|hiptop|iemobile|ip(hone|od)|iris|kindle|lge |maemo|midp|mmp|mobile.+firefox|netfront|opera m(ob|in)i|palm( os)?|phone|p(ixi|re)\\/|plucker|pocket|psp|series(4|6)0|symbian|treo|up\\.(browser|link)|vodafone|wap|windows (ce|phone)|xda|xiino/i.test( a ) || /1207|6310|6590|3gso|4thp|50[1-6]i|770s|802s|a wa|abac|ac(er|oo|s\\-)|ai(ko|rn)|al(av|ca|co)|amoi|an(ex|ny|yw)|aptu|ar(ch|go)|as(te|us)|attw|au(di|\\-m|r |s )|avan|be(ck|ll|nq)|bi(lb|rd
# ...

# %%
print(text)

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen("https://timesofindia.indiatimes.com/city/kolkata/engineering-student-brother-beat-up-dum-dum-sub-inspector/articleshow/65049669.cms").read().decode('utf8','ignore')
soap = BeautifulSoup(html,'lxml')
text = ' '.join(map(lambda p:p.text,soap.find_all('articleshow')))
#print(text.encode('utf8').rstrip("\n"))
ajith = text.encode('ascii',errors='replace').decode().replace("\n",".")
text
# Out:
# ''
